# %% [markdown]
# 問:想要用 Python 開發一個 Linebot 聊天機器人，並且可以呼叫 chatgpt api 作為回答，請問該如何開始?
#
# 答:
# <pre>
# 步驟 1: 註冊 Line 開發者帳號
# 首先，您需要在 Line 開發者平台註冊一個帳號。
# 登錄後，建立一個新的 Messaging API channel，以獲取 Linebot 的 Channel Access Token 和 Channel Secret。
# </pre>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <pre>
# 步驟 2: 安裝必要的套件
# 您需要安裝一些 Python 套件來開發 Linebot。其中包括 line-bot-sdk 用於與 Line Messaging API 進行通信，以及 requests 用於發送 API 請求。
#
# 您可以使用以下命令使用 pip 安裝這些套件：
#
#
# <pre>
#     pip install line-bot-sdk requests

# %%
from linebot import LineBotApi, WebhookHandler
from linebot.models import MessageEvent, TextMessage, TextSendMessage
import requests
line_bot_api = LineBotApi('YOUR_CHANNEL_ACCESS_TOKEN')
handler = WebhookHandler('YOUR_CHANNEL_SECRET')
